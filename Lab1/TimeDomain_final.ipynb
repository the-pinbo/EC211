# %% [markdown]
# ## Time domain processing of LTI systems
#
# For the LTI systems described by the following difference equations, generate its impulse response, and unit step response. Comment on the properties of the system (Stable, Causal)
#
#  <ol>
#   <li>$y[n] =    y[n-1] + x[n]  $  </li>
#   <li>$y[n] =    x[n]   - x[n-1]$  </li>
#   <li>$y[n] = 0.9y[n−1] + x[n]  $  </li>
#   <li>$y[n] = \frac{1}{4} \sum_{k=0}^3 x[n-k] $ </li>
# </ol>
#
# Also plot the input and output of these systems if you pass the following inputs
#
#  <ol>
#   <li>$ \sin\left[ 0.05\pi n  \right] (u[n] - u[n-100])$ </li>
#   <li>$ (-1)^n (u[n] - u[n-100]) $ </li>
#   <li>$ [(n\%10) -5](u[n] - u[n-100]) $ "%" denotes the reminder of division </li>
#   <li>$ (0.9)^n(u[n] - u[n-100]) $ </li>
# </ol>
#
# (use function <i>scipy.signal.impulse</i> to determine the impulse response and <i>scipy.signal.lfilter</i> to find the
# output)
#
# Details about <i>scipy.signal.impulse</i> can be found here, https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.signal.impulse.html#scipy.signal.impulse
#
# Details about <i>scipy.signal.lfilter</i> can be found here, https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.signal.lfilter.html#scipy.signal.lfilter

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import figure
import scipy.signal as sig

n = np.arange(-1, 120)
X = [0, 1, 0, 0, 0, 0, 0]


def impulse(n):
    if (n in range(-1, 5)):
        return X[n + 1]
    else:
        return 0


def unitstep(n):
    if (n >= 0):
        return 1
    else:
        return 0

# %% [markdown]
# 𝑦[𝑛]=𝑦[𝑛−1]+𝑥[𝑛] = it is a Causal but NOT stable
#
# 𝑦[𝑛]=𝑥[𝑛]−𝑥[𝑛−1] = it is causal and it is Stable
#
# 𝑦[𝑛]=0.9𝑦[𝑛−1]+𝑥[𝑛] = there are 2 Cases ...in one case (both stable and Causal) and other one is (both Not stable and not causal)
#
# 𝑦[𝑛]= 1/4 * summation k 0 to 3 x[n - k] = both causal and stable

# %%
#question 1) h[n] = h[n-1] + delta[n]   delta function is 1 only at n = 0
#OR pls look at a attached png file for slight modification of original equation to another form (easier to plot)
# when you replace x with delta for impulse response, we get h[n] = u[n]
x11 = np.array([unitstep(i) for i in n])
h11 = x11

# # question 2) unit[n] = unit[n-1] + u[u]
x1 = np.empty(11)
h21 = np.empty((0, 121), int)
for k in range(0, 120):
    h21 = np.append(h21, np.array([[unitstep(i - k) for i in n]]), axis=0)
h21 = np.sum(h21, axis=0)
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)  #Sharing Y axis
ax1.stem(n, h11)
ax1.set_title('impulse response')
ax2.stem(n, h21)
ax2.set_title('unit step response')
# Out:
# Text(0.5, 1.0, 'unit step response')

# %%
img = mpimg.imread('Q1.png', 0)
imgplot = plt.imshow(img)

# %%
#question 2) h[n] = delta[n] - delta[n-1]
x21 = np.array([impulse(i) for i in n])
x22 = -1 * np.array([impulse(i - 1) for i in n])
h21 = x21 + x22
#question 2) unit[n] = u[n] - u[n-1]
x21 = np.array([unitstep(i) for i in n])
x22 = -1 * np.array([unitstep(i - 1) for i in n])
h22 = x21 + x22

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)  #Sharing Y axis
ax1.stem(n, h21)
ax1.set_title('impulse response')
ax2.stem(n, h22)
ax2.set_title('unit step response')
# Out:
# Text(0.5, 1.0, 'unit step response')

# %%
#question 3) h[n] = 0.9*h[n-1] + delta[n]   delta function is 1 only at n = 0
#OR pls look at a attached png file for slight modification of original equation to another form (easier to plot)

x31 = np.power(0.9, n) * np.array([unitstep(i) for i in n])
h31 = x31

#question 3)
x1 = np.empty(11)
h32 = np.empty((0, 121), int)
for k in range(0, 120):
    h32 = np.append(h32,np.power(0.9, k) * np.array([[unitstep(i - k) for i in n]]),axis=0)
h32 = np.sum(h32, axis=0)

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)  #Sharing Y axis
ax1.stem(n, h31)
ax1.set_title('impulse response')
ax2.stem(n, h32)
ax2.set_title('unit step response')
# Out:
# Text(0.5, 1.0, 'unit step response')

# %%
#question 4) h[n] = 1/4 * summation till 3 delta[n - k]

x41 = np.array([unitstep(i) for i in n])
x42 = -1 * np.array([unitstep(i - 4) for i in n])
h41 = (0.25) * (x41 + x42)

#quesstion 4) unit[n] = 1/4 * summation till 3 unitstep[n - k]
x1 = np.empty(11)
h42 = np.empty((0, 121), int)
for k in range(0, 4):
    h42 = np.append(h42, np.array([[unitstep(i - k) for i in n]]), axis=0)
h42 = (0.25) * np.sum(h42, axis=0)

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)  #Sharing Y axis
ax1.stem(n, h41)
ax1.set_title('impulse response')
ax2.stem(n, h42)
ax2.set_title('unit step response')
# Out:
# Text(0.5, 1.0, 'unit step response')

# %%
# MAIN QUESTION 2 (I) X[N] = SIN[0.05pin](u[n] - u[n - 100])
# x51 = np.sin(0.05*np.pi*n)*(np.array([unitstep(i) for i in n]) - np.array([unitstep(i - 100) for i in n]))
# plt.stem(n,x51)

#y[n] = y[n-1] + x[n]  OR  y[n] = summation k = 0 to infinity x[n - k]
x1 = np.empty(11)
h51 = np.empty((0, 121), int)
h52 = np.empty((0, 121), int)
for k in range(0, 120):
    h51 = np.append(h51,
                np.sin(0.05 * np.pi * np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    h52 = np.append(h52,
                    np.sin(0.05 * np.pi * np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
h51 = np.sum(h51, axis=0)
h52 = np.sum(h52, axis=0)

plt.stem(n, h51 - h52)
plt.title('y[n] = y[n-1] + x[n] when x[n] is sin(0.05pin)(u[n] - n[n-100])')
# Out:
# Text(0.5, 1.0, 'y[n] = y[n-1] + x[n] when x[n] is sin(0.05pin)(u[n] - n[n-100])')

# %%
#y[n] = x[n] - x[n-1] when x[n] = sin(0.05pin)(u[n] - n[n-100])

h61 = np.sin(0.05 * np.pi * np.array([(i) for i in n])) * np.array(
    np.array([unitstep(i) for i in n]))
h62 = np.sin(0.05 * np.pi * np.array([(i - 1) for i in n])) * np.array(
    np.array([unitstep(i - 1) for i in n]))

plt.stem(n, h61 - h62)
plt.title('y[n] = x[n] - x[n-1] when x[n] = sin(0.05pin)(u[n] - n[n-100])')
# Out:
# Text(0.5, 1.0, 'y[n] = x[n] - x[n-1] when x[n] = sin(0.05pin)(u[n] - n[n-100])')

# %%
#y[n] = 0.9y[n-1] + x[n] when x[n] = sin(0.05pin)(u[n] - n[n-100])

x1 = np.empty(11)
h71 = np.empty((0, 121), int)
h72 = np.empty((0, 121), int)
for k in range(0, 120):
    h71 = np.append(h71,
                    np.power(0.9, k) *
                    np.sin(0.05 * np.pi * np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    h72 = np.append(h72,
                    np.power(0.9, k) *
                    np.sin(0.05 * np.pi * np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
h71 = np.sum(h71, axis=0)
h72 = np.sum(h72, axis=0)

plt.stem(n, h71 - h72)
plt.title('y[n]=0.9y[n-1] + x[n] when x[n] is sin(0.05pin)(u[n] - n[n-100])')
# Out:
# Text(0.5, 1.0, 'y[n]=0.9y[n-1] + x[n] when x[n] is sin(0.05pin)(u[n] - n[n-100])')

# %%
#y[n] = (0.25)summation k 0 to 3 when x[n] = sin(0.05pin)(u[n] - n[n-100])

x1 = np.empty(11)
h81 = np.empty((0, 121), int)
h82 = np.empty((0, 121), int)
for k in range(0, 4):
    h81 = np.append(h81,
                    np.sin(0.05 * np.pi * np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    h82 = np.append(h82,
                    np.sin(0.05 * np.pi * np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
h81 = (0.25) * np.sum(h81, axis=0)
h82 = (0.25) * np.sum(h82, axis=0)

plt.stem(n, h81 - h82)
plt.title('y[n] = (0.25)summation k 0 to 3 x[n-k] when x[n] is sin(0.05pin)(u[n] - n[n-100])')
# Out:
# Text(0.5, 1.0, 'y[n] = (0.25)summation k 0 to 3 x[n-k] when x[n] is sin(0.05pin)(u[n] - n[n-100])')

# %%
#NOW FOR THE INPUT X[N] = (-1)^N(u[n] - u[n - 100])
n1 = np.arange(0, 10)
input1 = np.power(-1, n1) * (np.array([unitstep(i) for i in n1]) -
                             np.array([unitstep(i - 100) for i in n1]))
plt.stem(n1, input1)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# #### y[n] = y[n-1] + x[n]  OR  y[n] = summation k = 0 to infinity x[n - k]

# %%
#y[n] = x[n] - x[n-1] when X[N] = (-1)^N(u[n] - u[n - 100])
x1 = np.empty(11)
j_1 = np.empty((0, 121), int)
j_2 = np.empty((0, 121), int)
for k in range(0, 120):
    j_1 = np.append(j_1,
                    np.float_power(-1, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    j_2 = np.append(j_2,
                    np.float_power(-1, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
j_1 = np.sum(j_1, axis=0)
j_2 = np.sum(j_2, axis=0)

plt.stem(n, j_1 - j_2)
plt.title('y[n] x[n] - x[n-1] when x[n] = -1^n(u[n]−u[n−100])')
# Out:
# Text(0.5, 1.0, 'y[n] x[n] - x[n-1] when x[n] = -1^n(u[n]−u[n−100])')

# %%
#y[n] = x[n] - x[n-1] when x[n] = -1^n(u[n]−u[n−100])
a_3 = np.float_power(-1, np.array([(i) for i in n])) * np.array(
    np.array([unitstep(i) for i in n]))
a_4 = np.float_power(-1, np.array([(i - 1) for i in n])) * np.array(
    np.array([unitstep(i - 1) for i in n]))

plt.stem(n, a_3 - a_4)
plt.title('y[n] = x[n] - x[n-1] when x[n] = (-1)^n(u[n]−u[n−100]')
# Out:
# Text(0.5, 1.0, 'y[n] = x[n] - x[n-1] when x[n] = (-1)^n(u[n]−u[n−100]')

# %%
#y[n] = 0.9y[n-1] + x[n] when x[n] = (-1)^n(u[n]−u[n−100])

x1 = np.empty(11)
a_5 = np.empty((0, 121), int)
a_6 = np.empty((0, 121), int)
for k in range(0, 120):
    a_5 = np.append(a_5,
                    np.power(0.9, k) *
                    np.float_power(-1, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    a_6 = np.append(a_6,
                    np.power(0.9, k) *
                    np.float_power(-1, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
a_5 = np.sum(a_5, axis=0)
a_6 = np.sum(a_6, axis=0)

plt.stem(n, a_5 - a_6)
plt.title('y[n]= 0.9y[n-1] + x[n] when x[n] = (-1)^n(u[n]−u[n−100]')
# Out:
# Text(0.5, 1.0, 'y[n]= 0.9y[n-1] + x[n] when x[n] = (-1)^n(u[n]−u[n−100]')

# %%
#y[n] = (0.25)summation k 0 to 3 when x[n] = (-1)^n(u[n]−u[n−100])

x1 = np.empty(11)
a_7 = np.empty((0, 121), int)
a_8 = np.empty((0, 121), int)
for k in range(0, 4):
    a_7 = np.append(a_7,
                    np.float_power(-1, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    a_8 = np.append(a_8,
                    np.float_power(-1, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
a_7 = (0.25) * np.sum(a_7, axis=0)
a_8 = (0.25) * np.sum(a_8, axis=0)

plt.stem(n, a_7 - a_8)
plt.title('y[n] (0.25)summation k 0 to 3 x[n-k] when x[n] = (-1)^n(u[n]−u[n−100])')
# Out:
# Text(0.5, 1.0, 'y[n] (0.25)summation k 0 to 3 x[n-k] when x[n] = (-1)^n(u[n]−u[n−100])')

# %%
#y[n] = y[n-1] + x[n] [(𝑛%10)−5](𝑢[𝑛]−𝑢[𝑛−100])
x1 = np.empty(11)
h_1 = np.empty((0, 121), int)
h_2 = np.empty((0, 121), int)
for k in range(0, 120):
    h_1 = np.append(h_1, ((np.array([(i - k) for i in n]) % 10) - 5) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    h_2 = np.append(h_2, ((np.array([(i - k) for i in n]) % 10) - 5) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
h_1 = np.sum(h_1, axis=0)
h_2 = np.sum(h_2, axis=0)

plt.stem(n, h_1 - h_2)
plt.title('y[n] = y[n-1] + x[n] when x[n] is [(n%10)−5](u[n]−u[n−100])')
# Out:
# Text(0.5, 1.0, 'y[n] = y[n-1] + x[n] when x[n] is [(n%10)−5](u[n]−u[n−100])')

# %%
#y[n] = x[n] - x[n-1] when x[n] is [(n%10)−5](u[n]−u[n−100])
h_3 = ((np.array([(i) for i in n]) % 10) - 5) * np.array(
    np.array([unitstep(i) for i in n]))
h_4 = ((np.array([(i - 1) for i in n]) % 10) - 5) * np.array(
    np.array([unitstep(i - 1) for i in n]))

plt.stem(n, h_3 - h_4)
plt.title('y[n] = x[n] - x[n-1] when x[n] is [(n%10)−5](u[n]−u[n−100])')
# Out:
# Text(0.5, 1.0, 'y[n] = x[n] - x[n-1] when x[n] is [(n%10)−5](u[n]−u[n−100])')

# %%
#y[n] = 0.9y[n-1] + x[n] when x[n] is [(n%10)−5](u[n]−u[n−100])

x1 = np.empty(11)
h_5 = np.empty((0, 121), int)
h_6 = np.empty((0, 121), int)
for k in range(0, 120):
    h_5 = np.append(h_5,
                    np.power(0.9, k) * ((np.array([(i - k)
                                                   for i in n]) % 10) - 5) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    h_6 = np.append(h_6,
                    np.power(0.9, k) * ((np.array([(i - k)
                                                   for i in n]) % 10) - 5) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
h_5 = np.sum(h_5, axis=0)
h_6 = np.sum(h_6, axis=0)

plt.stem(n, h_5 - h_6)
plt.title('y[n] = 0.9y[n-1] + x[n] when x[n] is sin(0.05pin)(u[n] - n[n-100])')
# Out:
# Text(0.5, 1.0, 'y[n] = 0.9y[n-1] + x[n] when x[n] is sin(0.05pin)(u[n] - n[n-100])')

# %%
#y[n] = (0.25)summation k 0 to 3 when x[n] is [(n%10)−5](u[n]−u[n−100])
x1 = np.empty(11)
n = np.arange(-1, 120)
h_7 = np.empty((0, 121), int)
h_8 = np.empty((0, 121), int)
for k in range(0, 4):
    h_7 = np.append(h_7, ((np.array([(i - k) for i in n]) % 10) - 5) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    h_8 = np.append(h_8, ((np.array([(i - k) for i in n]) % 10) - 5) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
h_7 = (0.25) * np.sum(h_7, axis=0)
h_8 = (0.25) * np.sum(h_8, axis=0)

plt.stem(n, h_7 - h_8)
plt.title('y[n] (0.25)summation k 0 to 3 x[n-k] when x[n] is [(n%10)−5](u[n]−u[n−100])')
# Out:
# Text(0.5, 1.0, 'y[n] (0.25)summation k 0 to 3 x[n-k] when x[n] is [(n%10)−5](u[n]−u[n−100])')

# %%
#y[n] = y[n-1] + x[n] when x[n] = (0.9)^n(u[n]−u[n−100])

x1 = np.empty(11)
j_1 = np.empty((0, 121), int)
j_2 = np.empty((0, 121), int)
for k in range(0, 120):
    j_1 = np.append(j_1,
                    np.float_power(0.9, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    j_2 = np.append(j_2,
                    np.float_power(0.9, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
j_1 = np.sum(j_1, axis=0)
j_2 = np.sum(j_2, axis=0)

plt.stem(n, j_1 - j_2)
plt.title('y[n] = y[n-1] + x[n] when x[n] = (0.9)^n(u[n]−u[n−100])')
# Out:
# Text(0.5, 1.0, 'y[n] = y[n-1] + x[n] when x[n] = (0.9)^n(u[n]−u[n−100])')

# %%
#y[n] = x[n] - x[n-1] when x[n] = (0.9)^n(u[n]−u[n−100])

j_3 = np.float_power(0.9, np.array([(i) for i in n])) * np.array(
    np.array([unitstep(i) for i in n]))
j_4 = np.float_power(0.9, np.array([(i - 1) for i in n])) * np.array(
    np.array([unitstep(i - 1) for i in n]))

plt.stem(n, j_3 - j_4)
plt.title('y[n] = x[n] - x[n-1] when x[n] = (0.9)^n(u[n]−u[n−100]')
# Out:
# Text(0.5, 1.0, 'y[n] = x[n] - x[n-1] when x[n] = (0.9)^n(u[n]−u[n−100]')

# %%
#y[n] = 0.9y[n-1] + x[n] when x[n] = (0.9)^n(u[n]−u[n−100])

x1 = np.empty(11)
j_5 = np.empty((0, 121), int)
j_6 = np.empty((0, 121), int)
for k in range(0, 120):
    j_5 = np.append(j_5,
                    np.power(0.9, k) *
                    np.float_power(0.9, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    j_6 = np.append(j_6,
                    np.power(0.9, k) *
                    np.float_power(0.9, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
j_5 = np.sum(j_5, axis=0)
j_6 = np.sum(j_6, axis=0)

plt.stem(n, j_5 - j_6)
plt.title('y[n] = 0.9y[n-1] + x[n] when x[n] = (0.9)^n(u[n]−u[n−100]')
# Out:
# Text(0.5, 1.0, 'y[n] = 0.9y[n-1] + x[n] when x[n] = (0.9)^n(u[n]−u[n−100]')

# %%
#y[n] = (0.25)summation k 0 to 3 when x[n] = (0.9)^n(u[n]−u[n−100])

x1 = np.empty(11)
j_7 = np.empty((0, 121), int)
j_8 = np.empty((0, 121), int)
for k in range(0, 4):
    j_7 = np.append(j_7,
                    np.float_power(0.9, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k) for i in n]]),
                    axis=0)
    j_8 = np.append(j_8,
                    np.float_power(0.9, np.array([(i - k) for i in n])) *
                    np.array([[unitstep(i - k - 100) for i in n]]),
                    axis=0)
j_7 = (0.25) * np.sum(j_7, axis=0)
j_8 = (0.25) * np.sum(j_8, axis=0)

plt.stem(n, j_7 - j_8)
plt.title('y[n] = (0.25)summation k 0 to 3 n[n-k] when x[n] = (0.9)^n(u[n]−u[n−100])')
# Out:
# Text(0.5, 1.0, 'y[n] = (0.25)summation k 0 to 3 n[n-k] when x[n] = (0.9)^n(u[n]−u[n−100])')

# %% [markdown]
# Plot the response of the following filters if the input is
# <ul>
#   <li>$x[n] = 0.1n + sin(0.1nπ);    0 ≤ n ≤ 60 $  </li>
# </ul>
#
# <ol>
#     <li> $y[n] = \frac{1}{4} \sum_{k=0}^3  x[n − k]$ </li>
#     <li>$y[n] = \frac{2}{N(N+1)} \sum_{k=0}^{N−1}(N − k)x[n − k]; N = 4$ </li>
#     <li>$y[n] − \alpha y[n − 1] = (1 − \alpha)x[n]; \alpha = 3/4 $ </li>
# </ol>

# %%
# 1) y[n] = (0.25)*summation k 0 to 3 x[n - k]
n_1 = np.arange(0, 61)
g_1 = np.empty((0, 61), int)
g_2 = np.empty((0, 61), int)
for k in range(0, 4):
    g_1 = np.append(g_1, 0.1 * np.array([[(i - k) for i in n_1]]), axis=0)
    g_2 = np.append(g_2,
                    np.sin(0.1 * np.pi * np.array([[(i - k) for i in n_1]])),
                    axis=0)
g_1 = (0.25) * np.sum(g_1, axis=0)
g_2 = (0.25) * np.sum(g_2, axis=0)

plt.ylim(-1, 7)
plt.stem(n_1, g_1 + g_2)
print(g_1 + g_2)
# Out:
# [-0.57645481 -0.19694631  0.19694631  0.57645481  0.91421894  1.18696469
#   1.37778251  1.47778251  1.48696469  1.41421894  1.27645481  1.09694631
#   0.90305369  0.72354519  0.58578106  0.51303531  0.52221749  0.62221749
#   0.81303531  1.08578106  1.42354519  1.80305369  2.19694631  2.57645481
#   2.91421894  3.18696469  3.37778251  3.47778251  3.48696469  3.41421894
#   3.27645481  3.09694631  2.90305369  2.72354519  2.58578106  2.51303531
#   2.52221749  2.62221749  2.81303531  3.08578106  3.42354519  3.80305369
#   4.19694631  4.57645481  4.91421894  5.18696469  5.37778251  5.47778251
#   5.48696469  5.41421894  5.27645481  5.09694631  4.90305369  4.72354519
#   4.58578106  4.51303531  4.52221749  4.62221749  4.81303531  5.08578106
#   5.42354519]

# %%
# 2) y[n] = 2/N(N+1)*summation k 0 to 3 (N-k)x[n-k]
N = 4
n_1 = np.arange(0, 61)
e_1 = np.empty((0, 61), int)
e_2 = np.empty((0, 61), int)
for k in range(0, 4):
    e_1 = np.append(e_1, (N - k) * 0.1 * np.array([[(i - k) for i in n_1]]),
                    axis=0)
    e_2 = np.append(e_2,
                    (N - k) * np.sin(0.1 * np.pi * np.array([[(i - k)
                                                              for i in n_1]])),
                    axis=0)
e_1 = (2 / (N * (N + 1))) * np.sum(e_1, axis=0)
e_2 = (2 / (N * (N + 1))) * np.sum(e_2, axis=0)

plt.ylim((-1, 6))
plt.stem(n_1, e_1 + e_2)
print(e_1 + e_2)
# Out:
# [-3.91163848e-01  3.02487365e-03  3.96917500e-01  7.61745772e-01
#   1.07158645e+00  1.30589888e+00  1.45153561e+00  1.50402940e+00
#   1.46803050e+00  1.35685142e+00  1.19116385e+00  9.96975126e-01
#   8.03082500e-01  6.38254228e-01  5.28413545e-01  4.94101121e-01
#   5.48464391e-01  6.95970596e-01  9.31969498e-01  1.24314858e+00
#   1.60883615e+00  2.00302487e+00  2.39691750e+00  2.76174577e+00
#   3.07158645e+00  3.30589888e+00  3.45153561e+00  3.50402940e+00
#   3.46803050e+00  3.35685142e+00  3.19116385e+00  2.99697513e+00
#   2.80308250e+00  2.63825423e+00  2.52841355e+00  2.49410112e+00
#   2.54846439e+00  2.69597060e+00  2.93196950e+00  3.24314858e+00
#   3.60883615e+00  4.00302487e+00  4.39691750e+00  4.76174577e+00
#   5.07158645e+00  5.30589888e+00  5.45153561e+00  5.50402940e+00
#   5.46803050e+00  5.35685142e+00  5.19116385e+00  4.99697513e+00
#   4.80308250e+00  4.63825423e+00  4.52841355e+00  4.49410112e+00
# ...

# %%
#since the above two graphs look the same (some scaled version is the difference)...I will print the y values to show the
#difference
#SEE THE DIFFERENT VALUES , SO THEY ARE NOT THE SAME

# %%
#3 y[n] = ay[n-1] + (1 - a)x[n] a = 3/4
img1 = mpimg.imread('Capture.png', 0)
imgplot = plt.imshow(img1)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import scipy.signal as sig

n=np.arange(0,61)
input=(0.1)*(n)+np.sin((0.1)*n*(np.pi)) #input
#for fxn3:
b1=[0.25]
a1=[1.0,-0.75]
responsec = sig.lfilter(b1,a1,input) #input applied on signal 3
responsec=list(responsec)
plt.stem(n,responsec,use_line_collection=True)
plt.xticks(np.arange(min(n), max(n)+1, 4.0))
plt.yticks(np.arange(0, 6.5, 0.5))
plt.title("Input on signal 3")
plt.show(responsec)
print(responsec)
# Out:
# [0.0, 0.10225424859373686, 0.2736369995184209, 0.48248199823255256, 0.6996256277482028, 0.8997192208111521, 1.0625535446821526, 1.1741694071053512, 1.2275733684021317, 1.2229342748953358, 1.167200706171502, 1.0731462810348895, 0.9579133977030488, 0.8411807996835499, 0.743121470688874, 0.6823411030166555, 0.6739916981887032, 0.7282395250477907, 0.8492333307127247, 1.0346707494408065, 1.2760030620806049, 1.5592565451541904, 1.8663887219387612, 2.177045790047808, 2.4705484716096446, 2.7279113537072335, 2.9336976443542135, 3.077527481859397, 3.1550919244676665, 3.168573191944487, 3.126429893958365, 3.042568171875037, 2.93497981583316, 2.823980613281133, 2.7302213308870615, 2.672665998165296, 2.6667353695501834, 2.7227972785689007, 2.8451516458535573, 3.0316094857964315, 3.2737071143473235, 3.5575345843542294, 3.8650972513387902, 4.17607718709783, 4.469822019397161, 4.727366514547871, 4.933289014984691, 5.077221009832256, 5.15486207044731, 5.168400801429219, 5.1263006010719145, 5.04247120
# ...

# %% [markdown]
# Consider a round theatre where an orchestra is in the middle of two concentric circles and the walls on one half side are at a radial distances of $17.15m$ (inner circle) and $34.3m$ (outer circle) on the other side from the
# orchestra. The speed of sound is $343 m/s$. Assume that the recorded signal is the sum of the original signal and the attenuated echoes from the two walls and is given by $r[n] = y[n] + 0.8y[n − N1] + 0.6y[n − N2]$ where,
# $N1$ is the delay caused by the closest wall and N2 is the delay caused by the farther wall. The recorder is in the centre of the theatre. Take any audio signal available and generate $r[n]$ and listen to both the original and
# the echoed signal.

# %%
import librosa

# %%
# Load an ogg vorbis file
filename = librosa.ex('trumpet')
y, sr = librosa.load(filename)
y
# Out:
# ...
# array([-1.4068224e-03, -4.4607223e-04, -4.1098078e-04, ...,
#         7.9623060e-06, -3.0417003e-05,  1.2765067e-05], dtype=float32)

# %%
sr
# Out:
# 22050

# %%
import matplotlib.pyplot as plt

plt.plot(y)

# %%
import IPython.display as ipd

# %%
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y.shape
# Out:
# (117601,)

# %%
n = np.arange(y.shape[0])
n
# Out:
# array([     0,      1,      2, ..., 117598, 117599, 117600])

# %%
# Delay for signals
# unit in seconds
T1 = 0.10
T2 = 0.20

# %%
N1 = (T1) * sr
N2 = (T2) * sr
N1, N2
# Out:
# (2205.0, 4410.0)

# %%
SIZE = max(N1, N2) + y.shape[0]
SIZE
# Out:
# 122011.0

# %% [markdown]
# 𝑟[𝑛]=𝑦[𝑛]+0.8𝑦[𝑛−𝑁1]+0.6𝑦[𝑛−𝑁2]

# %%
def yi(y,n0):
    ri = np.zeros(int(SIZE - n0 - y.size))
    le = np.zeros(int(n0))
    return np.concatenate((le,y,ri))

# %% [markdown]
# y1[𝑛]=𝑦[𝑛]

# %%
y1 = yi(y,0)
plt.plot(y1)

# %% [markdown]
# y2[𝑛]=0.8𝑦[𝑛−𝑁1]

# %%
y2 = yi(y,N1)
plt.plot(y2)

# %% [markdown]
# y3[𝑛]=0.6𝑦[𝑛−𝑁2]

# %%
y3 = yi(y,0)
plt.plot(y3)

# %% [markdown]
# 𝑟[𝑛]=𝑦[𝑛]+0.8𝑦[𝑛−𝑁1]+0.6𝑦[𝑛−𝑁2]

# %%
r = y1 + .8 * y2 + .6 * y3
r
# Out:
# array([-0.00225092, -0.00071372, -0.00065757, ...,  0.        ,
#         0.        ,  0.        ])

# %%
y.shape
# Out:
# (117601,)

# %%
plt.plot(r)

# %%
ipd.Audio(data=r, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
