# %% [markdown]
# # Discrete Fourier Transform

# %% [markdown]
# Q1. Compute the 8-point DFT of the following sequences. Plot the magnitude and phase spectrum. Observe the symmetry properties.
# <ol>
#   <li>x[n] = {1,1,0,0,0,0,0,1}</li>
#   <li>x[n] = {0,1,1,0,0,0,-1,-1}</li>
#   <li>x[n] = {1,1,1,1,1,1,1,1}</li>
# </ol>
#
# https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.fft.fft.html#numpy.fft.fft

# %%
import numpy as np
import matplotlib.pyplot as plt

#1
k = range(8)
a = np.array([1,1,0,0,0,0,0,1])
A = np.fft.fft(a,8)

print(A)

plt.stem(k,abs(A))
plt.title("magnitude spectrum")
plt.show()

angles = np.angle(A)
plt.stem(k, angles, 'g')
plt.title("phase spectrum")
plt.show()
# Out:
# [ 3.        +0.j  2.41421356+0.j  1.        +0.j -0.41421356+0.j
#  -1.        +0.j -0.41421356+0.j  1.        +0.j  2.41421356+0.j]

# %%
#2
k = range(8)
a = np.array([0,1,1,0,0,0,-1,-1])
A = np.fft.fft(a,8)

print(A)

plt.stem(k,abs(A))
plt.title("magnitude spectrum")
plt.show()

angles = np.angle(A)
plt.stem(k, angles, 'g')
plt.title("phase spectrum")
plt.show()
# Out:
# [0.+0.j         0.-3.41421356j 0.-2.j         0.+0.58578644j
#  0.+0.j         0.-0.58578644j 0.+2.j         0.+3.41421356j]

# %%
k = range(8)
a = np.array([1,1,1,1,1,1,1,1])
A = np.fft.fft(a,8)

print(A)

plt.stem(k,abs(A))
plt.title("magnitude spectrum")
plt.show()

angles = np.angle(A)
plt.stem(k, angles, 'g')
plt.title("phase spectrum")
plt.show()
# Out:
# [8.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %% [markdown]
# Q2. Generate the finite duration sequence $x[n] = 0.5(1-cos({\pi}n/20)), ~~0{\le}n{\lt}20$.
# <ol>
#   <li>Append the sequence with sufficient number of zeros to compute the DFT of the sequence with length N= 32 and 256. Plot the DFT and comment on the effects of zero padding</li>
#   <li>Insert 16 zeros in the beginning of the sequence and repeat.</li>
# </ol>

# %%
n = np.arange(0,20)
x = 0.5*(1 - np.cos(np.pi*n/20))
x_ = np.append(x,np.zeros(12))  # padded with zeros for N= 32 
x1_ = np.append(x,np.zeros(236)) # padded with zeros for N= 256 
 

N_ = np.arange(0,32)
X_ = np.fft.fft(x_,32)
plt.stem(N_,abs(X_))
plt.title("magnitude spectrum for N = 32")
plt.show()
print(abs(X_))

angles = np.angle(X_)
plt.stem(N_, angles, 'g')
plt.title("phase spectrum for N = 32")
plt.show()

N1_ = np.arange(0,256)
X1_ = np.fft.fft(x1_,256)
plt.figure(figsize = (15,4))
plt.stem(N1_,abs(X1_))
plt.title("magnitude spectrum for N = 256")
xmin,xmax = plt.xlim()
plt.xlim(xmin*0.2,xmax)
plt.show()
print(abs(X1_))

angles1 = np.angle(X1_)
plt.figure(figsize = (15,4))
plt.stem(N1_, angles1, 'g')
plt.title("phase spectrum for N = 256")
xmin,xmax = plt.xlim()
plt.xlim(xmin*0.2,xmax)
plt.show()
# Out:
# [9.5        6.94898879 2.85443295 1.81681466 1.30656296 1.0851849
#  0.9021387  0.79135043 0.71152752 0.64605287 0.60342664 0.5671405
#  1.92124529 1.9791215  2.05605532 2.16774643 2.33038065 2.55697456
#  2.85443295 3.22271155 3.65592556 4.14419781 4.67526875 5.23557427
#  5.81090239 6.38681769 6.94898879 7.48348811 7.97708971 8.41756794
#  8.79398908 9.09698451 9.31899325 9.4544629 ]

# %%
#2  INSERTED 16 ZEROS AT THE BEGINNING AND DONE  
N = np.arange(0,32)
n = np.arange(0,20)
x = np.zeros(16)  #added 16 zeros 
x = np.append(x,0.5*(1 - np.cos(np.pi*n/20)))


X = np.fft.fft(x,32)
plt.stem(N,abs(X))
plt.title("magnitude spectrum for N = 32 with 16 zeros")
plt.show()
print(abs(X))

angles = np.angle(X)
plt.stem(N, angles, 'g')
plt.title("phase spectrum for N = 32 with 16 zeros")
plt.show()

N = np.arange(0,256)
x1 = np.append(x,np.zeros(220))
X1 = np.fft.fft(x1,256)
plt.figure(figsize = (15,4))
plt.stem(N,abs(X1))
plt.title("magnitude spectrum for N = 256 with 16 zeros")
xmin,xmax = plt.xlim()
plt.xlim(xmin*0.2,xmax)
plt.show()
print(abs(X1))

angles = np.angle(X1)
plt.figure(figsize = (15,4))
plt.stem(N, angles, 'g')
plt.title("phase spectrum for N = 256 with 16 zeros")
xmin,xmax = plt.xlim()
plt.xlim(xmin*0.2,xmax)
plt.show()
# Out:
# [5.68061581 4.7089104  2.71388453 1.50963113 1.19840112 0.93319095
#  0.80533607 0.69413873 0.62744626 0.56990014 0.53160836 0.49962
#  0.47754967 0.46049765 0.44944253 0.44281945 0.44068932 0.44281945
#  0.44944253 0.46049765 0.47754967 0.49962    0.53160836 0.56990014
#  0.62744626 0.69413873 0.80533607 0.93319095 1.19840112 1.50963113
#  2.71388453 4.7089104 ]
# [9.5        9.4544629  9.31899325 9.09698451 8.79398908 8.41756794
#  7.97708971 7.48348811 6.94898879 6.38681769 5.81090239 5.23557427
#  4.67526875 4.14419781 3.65592556 3.22271155 2.85443295 2.55697456
#  2.33038065 2.16774643 2.05605532 1.9791215  1.92124529 1.86989898
#  1.81681466 1.75784218 1.69219438 1.6215046  1.54888668 1.47805436
#  1.41252077 1.35492338 1.30656296 1.26725469 1.23552873 1.20910527
#  1.18547879 1.16243953 1.13842419 1.11266822 1.0851849  1.05661633
#  1.02800257 1.00051226 0.9751787  0.95268693 0.93325256 0.91661504
#  0.9021387  0.88898579 0.87631041 0.86342617 0.84991643 0.83567597
#  0.82088739 0.80594579 0.79135043 0.77758578 0.76501553 0.75381069
#  0.74392577 0.73512514 0.72704905 0.71929998 0.71152752 0.70349367
#  0.69510781 0.68642804 0.67763258 0.66896928 0.66069497 0.65301757
#  0.64605287 0.63980483 0.63417206 0.62897716 0.62401023 0.61907531
#  0.61402957 0.60880747 0.60342664 0.59797586 0.59258917 0.58741238
#  0.58256953 0.57813639 0.57412667 0.57049281 0.5671405  0.56395224
#  0.56081414 0.55763948 0.55438451 0.55105358 0.54769357 0.54437968
#  0.5411961  0.5382163  0.53548709 0.53301993 0.53079081 0.52874812
#  0.52682607 0.52496011 0.52310076 0.52122278 0.51932815 0.51744276
#  0.51560802 0.5138697  0.51226692 0.51082356 0.50954408 0.50841432
#  0.50740659 0.5064875  0.5056263  0.50480175 0.50400589 0.50324415
#  0.50253208 0.50188987 0.50133627 0.50088358 0.50053494 0.50028455
#  0.50012048 0.50002913 0.5        0.50002913 0.50012048 0.50028455
#  0.50053494 0.50088358 0.50133627 0.50188987 0.50253208 0.50324415
#  0.50400589 0.50480175 0.5056263  0.5064875  0.50740659 0.50841432
#  0.50954408 0.51082356 0.51226692 0.5138697  0.51560802 0.51744276
#  0.51932815 0.52122278 0.52310076 0.52496011 0.52682607 0.52874812
#  0.53079081 0.53301993 0.53548709 0.5382163  0.5411961  0.54437968
#  0.54769357 0.55105358 0.55438451 0.55763948 0.56081414 0.56395224
#  0.5671405  0.57049281 0.57412667 0.57813639 0.58256953 0.58741238
#  0.59258917 0.59797586 0.60342664 0.60880747 0.61402957 0.61907531
#  0.62401023 0.62897716 0.63417206 0.63980483 0.64605287 0.65301757
#  0.66069497 0.66896928 0.67763258 0.68642804 0.69510781 0.70349367
#  0.71152752 0.71929998 0.72704905 0.73512514 0.74392577 0.75381069
#  0.76501553 0.77758578 0.79135043 0.80594579 0.82088739 0.83567597
#  0.84991643 0.86342617 0.87631041 0.88898579 0.9021387  0.91661504
#  0.93325256 0.95268693 0.9751787  1.00051226 1.02800257 1.05661633
#  1.0851849  1.11266822 1.13842419 1.16243953 1.18547879 1.20910527
#  1.23552873 1.26725469 1.30656296 1.35492338 1.41252077 1.47805436
#  1.54888668 1.6215046  1.69219438 1.75784218 1.81681466 1.86989898
#  1.92124529 1.9791215  2.05605532 2.16774643 2.33038065 2.55697456
#  2.85443295 3.22271155 3.65592556 4.14419781 4.67526875 5.23557427
#  5.81090239 6.38681769 6.94898879 7.48348811 7.97708971 8.41756794
#  8.79398908 9.09698451 9.31899325 9.4544629 ]

# %% [markdown]
# Q3. Plot the 32 point DFT of the following signals and comment on the spectral estimate.
# <ol>
#   <li>$x[n] = cos(3{\pi}n/8)$</li>
#   <li>$x[n] = cos(3{\pi}n/16)$</li>
#   <li>$x[n] = cos(3{\pi}n/17)$</li>
# </ol>

# %%
#1 
n = np.arange(32)
x1 = np.cos(3*np.pi*n/8)
X1 = np.fft.fft(x1,32)
plt.stem(n,abs(X1))
plt.title("magnitude spectrum for Q1")
plt.show()

angles1 = np.angle(X1)
plt.stem(n, angles1, 'g')
plt.title("phase spectrum for Q1")
plt.show()

#2
x2 = np.cos(3*np.pi*n/16)
X2 = np.fft.fft(x2,32)
plt.stem(n,abs(X2))
plt.title("magnitude spectrum for Q2")
plt.show()

angles2 = np.angle(X2)
plt.stem(n, angles2, 'g')
plt.title("phase spectrum for Q2")
plt.show()

#3
x3 = np.cos(3*np.pi*n/17)
X3 = np.fft.fft(x3,32)
plt.stem(n,abs(X3))
plt.title("magnitude spectrum for Q3")
plt.show()

angles3 = np.angle(X3)
plt.stem(n, angles3, 'g')
plt.title("phase spectrum for Q3")
plt.show()

# %% [markdown]
# Q4. Estimation of signal corrupted by noise: Generate the signal $s[n] = cos({\pi}5n/32) +cos({\pi}21n/64) $ for 256 samples. Generate a noisy version of the signal x[n]  by adding white gaussian noise e[n] with variance 0.3 to the original signal s[n]. Compute the energy in the error signal $\sum_{n}^{}(x[n] - s[n])^2$
# <ul>
#   <li>Plot the 256 point DFTs $S[k]$ and $X[k]$. Find the set $S_{nz}$ of the values of $k$ for which $S[k]$ is non-zero.</li>
#   <li>Find $\hat{X}[k] = X[k]$ if  $k~ \in \mathcal ~{S_{nz}}$ and zero otherwise. Find the IDFT $\hat{x}[n]$ from $\hat{X}[k]$ to recover the original signal. Plot $\hat{x}[n]$. Find the error signal energy after recovery $\sum_{n}^{}(\hat{x}[n] - s[n])^2$</li>
# </ul>

# %%
n = np.arange(0,256)
s = np.cos(np.pi*5*n/32) + np.cos(np.pi*21*n/64)

e_noise = np.random.normal(0,np.power(0.3,0.5),256)
x = s + e_noise

#energy of signal
error_signal = np.sum(np.power(x - s,2))
print(error_signal)

#plot DFT 
S = np.fft.fft(s,256)
plt.figure(figsize = (10,5))
plt.stem(n,abs(S))
plt.title("magnitude spectrum of 256 S[k]")
plt.show()
# print(abs(S))

angles = np.angle(S)
plt.figure(figsize = (15,4))
plt.stem(n, angles, 'g')
plt.title("Phase spectrum of 256 S[k]")
xmin,xmax = plt.xlim()
plt.xlim(xmin*0.2,xmax)
plt.show()

X = np.fft.fft(x,256)
plt.figure(figsize = (15,4))
plt.stem(n,abs(X))
plt.title("magnitude spectrum of 256 X[k]")
xmin,xmax = plt.xlim()
plt.xlim(xmin*0.2,xmax)
plt.show()

angles = np.angle(X)
plt.figure(figsize = (15,4))
plt.stem(n, angles, 'g')
plt.title("Phase spectrum of 256 X[k]")
xmin,xmax = plt.xlim()
plt.xlim(xmin*0.2,xmax)
plt.show()
# Out:
# 73.31741778066072

# %% [markdown]
# Q5. Generate the following signals $x_1[n] = cos({\pi}n/15),~~x_2[n] = cos(3{\pi}n/15)$ for n = 0 to 31. Plot the magnitude of 64 point DFT of the two signals $X_1[k]$ and $X_2[k]$ (with zero padding). Now concatenate the two signals to form a 64 length sequence $x[n]$. Plot the 64 point DFT magnitude $X[k]$ of $x[n]$. Also find the sum of two signals and plot the 64 point DFT of the result. (Based on the results, comment on the limitation of DFT.)

# %%
N = np.arange(0,64)
n = np.arange(0,32)
x1 = np.cos(np.pi*n/15)
y1 = np.append(x1,np.zeros(32))
x2 = np.cos(3*np.pi*n/15)
y2 = np.append(x2,np.zeros(32))

X1 = np.fft.fft(y1,64)
plt.stem(N,abs(X1))
plt.title("Magnitude spectrum for X1[k]")
plt.show()

angles = np.angle(X1)
plt.stem(N,angles,'g')
plt.title("Phase spectrum for X1[k]")
plt.show()

X2 = np.fft.fft(y2,64)
plt.stem(N,abs(X2))
plt.title("Magnitude spectrum for X2[k]")
plt.show()

angles = np.angle(X2)
plt.stem(N,angles,'g')
plt.show()

# %%
x = np.concatenate((x1,x2))
X = np.fft.fft(x,64)
plt.stem(N,abs(X))
plt.show()

angles = np.angle(X)
plt.stem(N,angles,'g')
plt.show()

# %%
z = np.vstack([x1,x2])
z = np.sum([z[0],z[1]], axis=0)
z = np.append(z,np.zeros(32))

Z = np.fft.fft(z,64)
plt.stem(N,abs(Z))
plt.show()

angles = np.angle(Z)
plt.stem(N,angles,'g')
plt.show()
